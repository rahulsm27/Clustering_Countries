# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from keras.datasets import mnist

# %%
data = mnist.load_data()

# %%
arr1 = data[1][0].reshape(10000,28*28)

# %%
arr2 = data[1][1]

# %%
arr1.shape
# Out:
# (10000, 784)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
df1 = pd.DataFrame(pca.fit_transform(arr1), columns = ["Col1","Col2"])

# %%
sns.jointplot(data=df1, x='Col1', y='Col2', hue=arr2)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(perplexity=20, n_components=2)

# %%
df2 = tsne.fit_transform(arr1)

# %%
df2 = pd.DataFrame(df2, columns = ["Col1","Col2"])

# %%
sns.jointplot(data=df2, x='Col1', y='Col2', hue=arr2)

# %%
tsne.kl_divergence_
# Out:
# 1.8388879299163818
